# %%
# This imports your tools (like getting your calculator and ruler ready)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Let's create some fake data to play with
heights = [150, 160, 170, 165, 175, 180, 155]
weights = [45, 55, 70, 60, 75, 80, 50]

# Make a simple graph
plt.scatter(heights, weights)
plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')
plt.title('My First ML Graph!')
plt.show()
